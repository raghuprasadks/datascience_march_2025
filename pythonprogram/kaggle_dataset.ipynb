# %%
# 1. Install Kaggle (if not already installed)
# !pip install kaggle
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 2. Set up Kaggle API credentials
import os

# Assume you have saved your kaggle.json somewhere, like:
kaggle_json_path = r"C:\Users\basavaraj\kaggle\kaggle.json"  # Change this to your path

# Make the hidden .kaggle folder if not exists
os.makedirs(os.path.expanduser('~/.kaggle'), exist_ok=True)

# Copy the kaggle.json file to the .kaggle directory
import shutil
shutil.copy(kaggle_json_path, os.path.expanduser('~/.kaggle/kaggle.json'))

# Set permissions (important on Linux/Mac; optional for Windows)
# !chmod 600 ~/.kaggle/kaggle.json

# 3. Download a dataset using kaggle CLI
# Example: Wine Reviews dataset
# !kaggle datasets download -d zynicide/wine-reviews

# 4. Unzip the downloaded dataset
import zipfile

with zipfile.ZipFile('wine-reviews.zip', 'r') as zip_ref:
    zip_ref.extractall('wine_reviews')

# 5. Load the dataset with Pandas
import pandas as pd

df = pd.read_csv('wine_reviews/winemag-data-130k-v2.csv')

# 6. See the first few rows
print(df.head())

# 7. Optional: Plotting
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.hist(df['points'], bins=20, color='coral', edgecolor='black')
plt.title('Distribution of Wine Points')
plt.xlabel('Points')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# 'chmod' is not recognized as an internal or external command,
# operable program or batch file.
# Dataset URL: https://www.kaggle.com/datasets/zynicide/wine-reviews
# License(s): CC-BY-NC-SA-4.0
# wine-reviews.zip: Skipping, found more recently modified local copy (use --force to force download)
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...
