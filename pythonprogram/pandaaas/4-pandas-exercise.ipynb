# %%
import pandas as pd

df=pd.read_csv('bad-data2.csv')
print(df.to_string())
# Out:
#     Steps           Day HeartRate  PeakRate  Energy
# 0    5000  '2024/01/01'        80       120   250.5
# 1    5200  '2024/01/02'        85       130   270.8
# 2    4800  '2024/01/03'        78       125   230.0
# 3    4500  '2024/01/04'        82       140   220.4
# 4    4600  '2024/01/05'        88       145   260.0
# 5    4900  '2024/01/06'        76       110   200.0
# 6    5100  '2024/01/07'        84       122   245.0
# 7   30000  '2024/01/08'        79       121   180.3
# 8    3000  '2024/01/09'        81       118   150.1
# 9    5300  '2024/01/10'        75       108   190.0
# 10   5000  '2024/01/11'        80       135   225.3
# 11   5100  '2024/01/12'        82       115   200.7
# 12   5100  '2024/01/12'        82       115   200.7
# 13   5200  '2024/01/13'        86       119   210.3
# 14   4800  '2024/01/14'        79       121   250.3
# 15   4600  '2024/01/15'        74       109   175.0
# 16   4700  '2024/01/16'        77       113   160.2
# ...

# %%
#print(df.duplicated())

df = df.drop_duplicates()
print(df.to_string())
# Out:
#     Steps           Day HeartRate  PeakRate  Energy
# 0    5000  '2024/01/01'        80       120   250.5
# 1    5200  '2024/01/02'        85       130   270.8
# 2    4800  '2024/01/03'        78       125   230.0
# 3    4500  '2024/01/04'        82       140   220.4
# 4    4600  '2024/01/05'        88       145   260.0
# 5    4900  '2024/01/06'        76       110   200.0
# 6    5100  '2024/01/07'        84       122   245.0
# 7   30000  '2024/01/08'        79       121   180.3
# 8    3000  '2024/01/09'        81       118   150.1
# 9    5300  '2024/01/10'        75       108   190.0
# 10   5000  '2024/01/11'        80       135   225.3
# 11   5100  '2024/01/12'        82       115   200.7
# 13   5200  '2024/01/13'        86       119   210.3
# 14   4800  '2024/01/14'        79       121   250.3
# 15   4600  '2024/01/15'        74       109   175.0
# 16   4700  '2024/01/16'        77       113   160.2
# 17   5100  '2024/01/17'        83       116   190.0
# ...

# %%
x = df["Energy"].median()
df["Energy"].fillna(x, inplace=True)  # Fill missing Energy with median

print(df.to_string())
# Out:
#     Steps           Day HeartRate  PeakRate  Energy
# 0    5000  '2024/01/01'        80       120   250.5
# 1    5200  '2024/01/02'        85       130   270.8
# 2    4800  '2024/01/03'        78       125   230.0
# 3    4500  '2024/01/04'        82       140   220.4
# 4    4600  '2024/01/05'        88       145   260.0
# 5    4900  '2024/01/06'        76       110   200.0
# 6    5100  '2024/01/07'        84       122   245.0
# 7   30000  '2024/01/08'        79       121   180.3
# 8    3000  '2024/01/09'        81       118   150.1
# 9    5300  '2024/01/10'        75       108   190.0
# 10   5000  '2024/01/11'        80       135   225.3
# 11   5100  '2024/01/12'        82       115   200.7
# 13   5200  '2024/01/13'        86       119   210.3
# 14   4800  '2024/01/14'        79       121   250.3
# 15   4600  '2024/01/15'        74       109   175.0
# 16   4700  '2024/01/16'        77       113   160.2
# 17   5100  '2024/01/17'        83       116   190.0
# ...

# %%
df.loc[7, 'Steps']=5000
print(df.to_string())
# Out:
#     Steps           Day HeartRate  PeakRate  Energy
# 0    5000  '2024/01/01'        80       120   250.5
# 1    5200  '2024/01/02'        85       130   270.8
# 2    4800  '2024/01/03'        78       125   230.0
# 3    4500  '2024/01/04'        82       140   220.4
# 4    4600  '2024/01/05'        88       145   260.0
# 5    4900  '2024/01/06'        76       110   200.0
# 6    5100  '2024/01/07'        84       122   245.0
# 7    5000  '2024/01/08'        79       121   180.3
# 8    3000  '2024/01/09'        81       118   150.1
# 9    5300  '2024/01/10'        75       108   190.0
# 10   5000  '2024/01/11'        80       135   225.3
# 11   5100  '2024/01/12'        82       115   200.7
# 13   5200  '2024/01/13'        86       119   210.3
# 14   4800  '2024/01/14'        79       121   250.3
# 15   4600  '2024/01/15'        74       109   175.0
# 16   4700  '2024/01/16'        77       113   160.2
# 17   5100  '2024/01/17'        83       116   190.0
# ...

# %%
df.dropna(inplace = True)
print(df.to_string())
# Out:
#     Steps           Day HeartRate  PeakRate  Energy
# 0    5000  '2024/01/01'        80       120   250.5
# 1    5200  '2024/01/02'        85       130   270.8
# 2    4800  '2024/01/03'        78       125   230.0
# 3    4500  '2024/01/04'        82       140   220.4
# 4    4600  '2024/01/05'        88       145   260.0
# 5    4900  '2024/01/06'        76       110   200.0
# 6    5100  '2024/01/07'        84       122   245.0
# 7    5000  '2024/01/08'        79       121   180.3
# 8    3000  '2024/01/09'        81       118   150.1
# 9    5300  '2024/01/10'        75       108   190.0
# 10   5000  '2024/01/11'        80       135   225.3
# 11   5100  '2024/01/12'        82       115   200.7
# 13   5200  '2024/01/13'        86       119   210.3
# 14   4800  '2024/01/14'        79       121   250.3
# 15   4600  '2024/01/15'        74       109   175.0
# 16   4700  '2024/01/16'        77       113   160.2
# 17   5100  '2024/01/17'        83       116   190.0
# ...
